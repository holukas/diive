# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     XGBoost gap-filling
# </b>: Minimal example
# </span>

# %% [markdown]
# ---
# **Notebook version**: `1` (26 Apr 2024)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %% [markdown]
# # **Background**

# %% [markdown]
# - Using [XGBoost](https://xgboost.readthedocs.io/en/stable/) to gap-fill time series data

# %% [markdown]
# </br>

# %% [markdown]
# # **User settings**
# `TARGET_COL` ... name of the time series that is gap-filled
# `subsetcols` ... list of columns included in the random forest model, target must also be listed here
#
# All columns that are not the target will be used as features/predictors during model building.

# %%
TARGET_COL = 'NEE_CUT_REF_orig'
subsetcols = [TARGET_COL, 'Tair_f', 'VPD_f', 'Rg_f']

# %% [markdown]
# </br>

# %% [markdown]
# # **Imports**
# - This notebook uses `diive` ([source code](https://gitlab.ethz.ch/diive/diive)) to check eddy covariance fluxes for quality

# %%
import importlib.metadata
import warnings
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np

from diive.configs.exampledata import load_exampledata_parquet
from diive.core.dfun.stats import sstats  # Time series stats
from diive.core.plotting.heatmap_datetime import HeatmapDateTime
from diive.core.plotting.timeseries import TimeSeries  # For simple (interactive) time series plotting
from diive.pkgs.gapfilling.xgboost_ts import XGBoostTS
from diive.core.ml.feature_engineer import FeatureEngineer

warnings.filterwarnings('ignore')
version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
# Out:
# diive version: v0.90.0

# %% [markdown]
# </br>

# %% [markdown]
# # **Docstring** for `XGBoostTS`

# %%
# help(XGBoostTS)

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **Load data**

# %% [markdown]
# ## Load example data from parquet file

# %%
source_df = load_exampledata_parquet()
# Out:
# Loaded .parquet file F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\configs\exampledata\exampledata_PARQUET_CH-DAV_FP2022.5_2013-2022_ID20230206154316_30MIN.parquet (0.071 seconds).
#     --> Detected time resolution of <30 * Minutes> / 30min

# %% [markdown]
# ## Make subset

# %%
df = source_df.copy()
lowquality = df[
                 "QCF_NEE"] > 0  # This example uses NEE flux data, only records where the quality flag QCF is 0 (highest quality) are retained
df.loc[lowquality, TARGET_COL] = np.nan  # Set fluxes of lower quality to missing
df = df[subsetcols].copy()  # Keep subset columns only

# %%
df.describe()
# Out:
#        NEE_CUT_REF_orig         Tair_f          VPD_f           Rg_f
# count      41284.000000  175296.000000  175296.000000  175296.000000
# mean          -3.833522       4.712999       3.233176     152.671445
# std            6.085449       7.548653       3.710180     247.531312
# min          -38.653000     -23.096000       0.000000       0.000000
# 25%           -7.840000      -0.800000       0.661000       0.000000
# 50%           -3.827000       4.600000       1.991000       2.596000
# 75%            0.606250      10.067000       4.375000     225.677750
# max           25.290000      28.713000      32.118000    1197.800000

# %%
sstats(df[TARGET_COL])
# Out:
#                 NEE_CUT_REF_orig
# STARTDATE       2013-01-01 00:15
# ENDDATE         2022-12-31 23:45
# PERIOD        3651 days 23:30:00
# NOV                        41284
# MISSING                   134012
# MISSING_PERC           76.448978
# MEAN                   -3.833522
# MEDIAN                    -3.827
# SD                      6.085449
# VAR                    37.032694
# SD/MEAN                 -1.58743
# SUM                  -158263.133
# MIN                      -38.653
# MAX                        25.29
# P01                     -18.7924
# P05                     -13.7397
# P25                        -7.84
# P75                      0.60625
# P95                      5.48585
# P99                     10.92289

# %%
# TimeSeries(series=df[TARGET_COL]).plot_interactive()
TimeSeries(series=df[TARGET_COL]).plot()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# # **Gap-filling**

# %% [markdown]
# ## Initialize XGBoost

# %%
# Note: No feature engineering needed for minimal example
# (Using only default features from input columns)
# To add feature engineering, see XGBoostGapFillingExtensive.ipynb

# Step 1: Create gap-filling model
xgbts = XGBoostTS(
    input_df=df,
    target_col=TARGET_COL,
    n_estimators=99,
    random_state=42,  # To keep results consistent between runs
    n_jobs=-1  # Use all available CPU cores
)

# %% [markdown]
# </br>

# %% [markdown]
# ## Feature reduction

# %%
xgbts.reduce_features()
# Out:
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [0]	validation_0-rmse:5.01108	validation_1-rmse:5.01108
# [1]	validation_0-rmse:4.35933	validation_1-rmse:4.35933
# [2]	validation_0-rmse:3.98451	validation_1-rmse:3.98451
# [3]	validation_0-rmse:3.76789	validation_1-rmse:3.76789
# [4]	validation_0-rmse:3.64007	validation_1-rmse:3.64007
# [5]	validation_0-rmse:3.57429	validation_1-rmse:3.57429
# [6]	validation_0-rmse:3.52608	validation_1-rmse:3.52608
# [7]	validation_0-rmse:3.49588	validation_1-rmse:3.49588
# [8]	validation_0-rmse:3.47963	validation_1-rmse:3.47963
# [9]	validation_0-rmse:3.46211	validation_1-rmse:3.46211
# [10]	validation_0-rmse:3.44841	validation_1-rmse:3.44841
# [11]	validation_0-rmse:3.43867	validation_1-rmse:3.43867
# [12]	validation_0-rmse:3.43220	validation_1-rmse:3.43220
# [13]	validation_0-rmse:3.42738	validation_1-rmse:3.42738
# [14]	validation_0-rmse:3.41881	validation_1-rmse:3.41881
# [15]	validation_0-rmse:3.41232	validation_1-rmse:3.41232
# [16]	validation_0-rmse:3.40303	validation_1-rmse:3.40303
# [17]	validation_0-rmse:3.39890	validation_1-rmse:3.39890
# [18]	validation_0-rmse:3.39482	validation_1-rmse:3.39482
# [19]	validation_0-rmse:3.38776	validation_1-rmse:3.38776
# [20]	validation_0-rmse:3.38041	validation_1-rmse:3.38041
# [21]	validation_0-rmse:3.37600	validation_1-rmse:3.37600
# [22]	validation_0-rmse:3.36962	validation_1-rmse:3.36962
# [68]	validation_0-rmse:3.13368	validation_1-rmse:3.13368
# [69]	validation_0-rmse:3.12897	validation_1-rmse:3.12897
# [70]	validation_0-rmse:3.12280	validation_1-rmse:3.12280
# [71]	validation_0-rmse:3.11954	validation_1-rmse:3.11954
# [72]	validation_0-rmse:3.11796	validation_1-rmse:3.11796
# [73]	validation_0-rmse:3.11593	validation_1-rmse:3.11593
# [74]	validation_0-rmse:3.11395	validation_1-rmse:3.11395
# [75]	validation_0-rmse:3.10909	validation_1-rmse:3.10909
# [76]	validation_0-rmse:3.10507	validation_1-rmse:3.10507
# [77]	validation_0-rmse:3.09958	validation_1-rmse:3.09958
# [78]	validation_0-rmse:3.09677	validation_1-rmse:3.09677
# [79]	validation_0-rmse:3.09025	validation_1-rmse:3.09025
# [80]	validation_0-rmse:3.08884	validation_1-rmse:3.08884
# [81]	validation_0-rmse:3.08520	validation_1-rmse:3.08520
# [82]	validation_0-rmse:3.08156	validation_1-rmse:3.08156
# [83]	validation_0-rmse:3.08010	validation_1-rmse:3.08010
# [84]	validation_0-rmse:3.07740	validation_1-rmse:3.07740
# [85]	validation_0-rmse:3.07254	validation_1-rmse:3.07254
# [86]	validation_0-rmse:3.06778	validation_1-rmse:3.06778
# [87]	validation_0-rmse:3.06255	validation_1-rmse:3.06255
# [88]	validation_0-rmse:3.06100	validation_1-rmse:3.06100
# [89]	validation_0-rmse:3.05834	validation_1-rmse:3.05834
# [90]	validation_0-rmse:3.05290	validation_1-rmse:3.05290
# [91]	validation_0-rmse:3.04763	validation_1-rmse:3.04763
# [92]	validation_0-rmse:3.04463	validation_1-rmse:3.04463
# [93]	validation_0-rmse:3.03847	validation_1-rmse:3.03847
# [94]	validation_0-rmse:3.03517	validation_1-rmse:3.03517
# [95]	validation_0-rmse:3.03322	validation_1-rmse:3.03322
# [96]	validation_0-rmse:3.03179	validation_1-rmse:3.03179
# [97]	validation_0-rmse:3.02958	validation_1-rmse:3.02958
# [98]	validation_0-rmse:3.02599	validation_1-rmse:3.02599
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 10 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.05305368823908133.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#         PERM_IMPORTANCE
# Rg_f           1.466957
# Tair_f         0.977110
# VPD_f          0.476489
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
# Empty DataFrame
# Columns: [PERM_IMPORTANCE]
# Index: []
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...

# %%
xgbts.report_feature_reduction()
# Out:
# =================
# FEATURE REDUCTION
# =================
#
# - Target variable: NEE_CUT_REF_orig
#
# - The random variable .RANDOM was added to the original features, used as benchmark for detecting relevant feature importances.
#
# PERMUTATION IMPORTANCE (mean) across all splits of TimeSeriesSplit:
#
#          PERM_IMPORTANCE   PERM_SD
# Rg_f            1.466957  0.014721
# Tair_f          0.977110  0.004135
# VPD_f           0.476489  0.003326
# .RANDOM         0.053054  0.000362
#
# - These results are from feature reduction. Note that feature importances for the final model are calculated during gap-filling.
#
# --> 3 original input features (before feature reduction): ['Tair_f', 'VPD_f', 'Rg_f']
# --> 5 rejected features (during feature reduction): None.
# --> 3 accepted features (after feature reduction): ['Rg_f', 'Tair_f', 'VPD_f']

# %% [markdown]
# </br>

# %% [markdown]
# ## Train model

# %%
xgbts.trainmodel(showplot_scores=True, showplot_importance=True)
# Out:
# Training final model ...
# >>> Training model <class 'xgboost.sklearn.XGBRegressor'> based on data between 2013-01-01 01:45:00 and 2022-12-31 22:15:00 ...
# >>> Fitting model to training data ...
# [0]	validation_0-rmse:5.01108	validation_1-rmse:5.05953
# [1]	validation_0-rmse:4.35951	validation_1-rmse:4.42750
# [2]	validation_0-rmse:3.98517	validation_1-rmse:4.06539
# [3]	validation_0-rmse:3.76884	validation_1-rmse:3.85628
# [4]	validation_0-rmse:3.64142	validation_1-rmse:3.73519
# [5]	validation_0-rmse:3.57611	validation_1-rmse:3.67822
# [6]	validation_0-rmse:3.52944	validation_1-rmse:3.63491
# [7]	validation_0-rmse:3.50143	validation_1-rmse:3.61349
# [8]	validation_0-rmse:3.48092	validation_1-rmse:3.59861
# [9]	validation_0-rmse:3.46514	validation_1-rmse:3.58808
# [10]	validation_0-rmse:3.45432	validation_1-rmse:3.58406
# [11]	validation_0-rmse:3.44647	validation_1-rmse:3.58118
# [12]	validation_0-rmse:3.43922	validation_1-rmse:3.58045
# [13]	validation_0-rmse:3.43482	validation_1-rmse:3.58008
# [14]	validation_0-rmse:3.42532	validation_1-rmse:3.57856
# [15]	validation_0-rmse:3.42125	validation_1-rmse:3.57860
# [16]	validation_0-rmse:3.41639	validation_1-rmse:3.57600
# [17]	validation_0-rmse:3.41348	validation_1-rmse:3.57522
# [18]	validation_0-rmse:3.40892	validation_1-rmse:3.57528
# [19]	validation_0-rmse:3.40439	validation_1-rmse:3.57451
# [20]	validation_0-rmse:3.40211	validation_1-rmse:3.57520
# [21]	validation_0-rmse:3.39646	validation_1-rmse:3.57518
# [22]	validation_0-rmse:3.39328	validation_1-rmse:3.57572
# [23]	validation_0-rmse:3.38888	validation_1-rmse:3.57730
# [24]	validation_0-rmse:3.38597	validation_1-rmse:3.57744
# [25]	validation_0-rmse:3.37556	validation_1-rmse:3.57619
# [26]	validation_0-rmse:3.36969	validation_1-rmse:3.57666
# [27]	validation_0-rmse:3.36490	validation_1-rmse:3.57616
# [28]	validation_0-rmse:3.36327	validation_1-rmse:3.57548
# [29]	validation_0-rmse:3.35827	validation_1-rmse:3.57684
# [30]	validation_0-rmse:3.35286	validation_1-rmse:3.57916
# [31]	validation_0-rmse:3.34942	validation_1-rmse:3.57889
# [32]	validation_0-rmse:3.34398	validation_1-rmse:3.57947
# [77]	validation_0-rmse:3.17697	validation_1-rmse:3.60589
# [78]	validation_0-rmse:3.17457	validation_1-rmse:3.60817
# [79]	validation_0-rmse:3.17112	validation_1-rmse:3.60879
# [80]	validation_0-rmse:3.16647	validation_1-rmse:3.60836
# [81]	validation_0-rmse:3.16160	validation_1-rmse:3.60856
# [82]	validation_0-rmse:3.15823	validation_1-rmse:3.60866
# [83]	validation_0-rmse:3.15409	validation_1-rmse:3.60915
# [84]	validation_0-rmse:3.15025	validation_1-rmse:3.61071
# [85]	validation_0-rmse:3.14574	validation_1-rmse:3.61140
# [86]	validation_0-rmse:3.14287	validation_1-rmse:3.61192
# [87]	validation_0-rmse:3.13767	validation_1-rmse:3.61372
# [88]	validation_0-rmse:3.13508	validation_1-rmse:3.61389
# [89]	validation_0-rmse:3.13173	validation_1-rmse:3.61464
# [90]	validation_0-rmse:3.12706	validation_1-rmse:3.61612
# [91]	validation_0-rmse:3.12556	validation_1-rmse:3.61662
# [92]	validation_0-rmse:3.12209	validation_1-rmse:3.61653
# [93]	validation_0-rmse:3.11805	validation_1-rmse:3.61698
# [94]	validation_0-rmse:3.11561	validation_1-rmse:3.61708
# [95]	validation_0-rmse:3.11232	validation_1-rmse:3.61828
# [96]	validation_0-rmse:3.10788	validation_1-rmse:3.61868
# [97]	validation_0-rmse:3.10380	validation_1-rmse:3.61998
# [98]	validation_0-rmse:3.10170	validation_1-rmse:3.62092
# >>> Using model to predict target NEE_CUT_REF_orig in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Plotting feature importances (permutation importance) ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_CUT_REF_orig ...
# >>> Plotting observed and predicted values ...
# >>> Plotting residuals and prediction error ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.

# %%
xgbts.report_traintest()
# Out:
# ================================
# MODEL TRAINING & TESTING RESULTS
# ================================
#
# ## DATA
#   > target: NEE_CUT_REF_orig
#   > features: 3 ['Rg_f', 'Tair_f', 'VPD_f']
#   > 175296 records (with missing)
#   > 41284 available records for target and all features (no missing values)
#   > training on 30963 records (75.0%) of 30963 features between 2013-01-01 01:45:00 and 2022-12-31 22:15:00
#   > testing on 10321 unseen records (25.0%) of NEE_CUT_REF_orig between 2013-01-01 06:15:00 and 2022-12-29 17:45:00
#
# ## MODEL
#   > the model was trained on training data (30963 records)
#   > the model was tested on test data (10321 values)
#   > estimator:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=99,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   > parameters:  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'feature_weights': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': None, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': None, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 99, 'n_jobs': -1, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#   > number of features used in model:  3
#   > names of features used in model:  ['Rg_f', 'Tair_f', 'VPD_f']
#
# ## FEATURE IMPORTANCES
#   > feature importances were calculated based on unseen test data of NEE_CUT_REF_orig (10321 records).
#   > feature importances are showing permutation importances from 10 repeats
#
#         PERM_IMPORTANCE   PERM_SD
# Rg_f           1.423511  0.015908
# Tair_f         0.970358  0.014221
# VPD_f          0.488009  0.014031
#
#
# ## MODEL SCORES
#   All scores were calculated based on unseen test data (10321 records).
#   > MAE:  2.6294361395765646 (mean absolute error)
#   > MedAE:  1.9477051467895503 (median absolute error)
#   > MSE:  13.111026813071357 (mean squared error)
#   > RMSE:  3.620915189986001 (root mean squared error)
#   > MAXE:  30.350757015228268 (max error)
#   > MAPE:  544311419547.843 (mean absolute percentage error)
#   > R2:  0.6480447994568217

# %% [markdown]
# </br>

# %% [markdown]
# ## Apply model to fill gaps

# %%
xgbts.fillgaps(showplot_scores=True, showplot_importance=True)
# Out:
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_CUT_REF_orig ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Plotting feature importances (permutation importance) ...
# >>> Calculating prediction scores based on all data predicting NEE_CUT_REF_orig ...
# >>> Plotting observed and predicted values based on all data ...
# >>> Predicting target NEE_CUT_REF_orig where all features are available ... predicted 175296 records.
# >>> Collecting results for final model ...
# >>> Filling 134012 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_CUT_REF_orig_gfXG ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_CUT_REF_orig_gfXG using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...

# %%
xgbts.report_gapfilling()
# Out:
# ===================
# GAP-FILLING RESULTS
# ===================
#
# Model scores and feature importances were calculated from high-quality predicted targets (134012 values, NEE_CUT_REF_orig_gfXG where flag=1) in comparison to observed targets (41284 values, NEE_CUT_REF_orig).
#
# ## TARGET
# - first timestamp:  2013-01-01 00:15:00
# - last timestamp:  2022-12-31 23:45:00
# - potential number of values: 175296 values)
# - target column (observed):  NEE_CUT_REF_orig
# - missing records (observed):  134012 (cross-check from flag: 134012)
# - target column (gap-filled):  NEE_CUT_REF_orig_gfXG  (175296 values)
# - missing records (gap-filled):  0
# - gap-filling flag: FLAG_NEE_CUT_REF_orig_gfXG_ISFILLED
#   > flag 0 ... observed targets (41284 values)
#   > flag 1 ... targets gap-filled with high-quality, all features available (134012 values)
#   > flag 2 ... targets gap-filled with fallback (0 values)
#
# ## FEATURE IMPORTANCES
# - names of features used in model:  ['Rg_f', 'Tair_f', 'VPD_f']
# - number of features used in model:  3
# - permutation importances were calculated from 10 repeats.
#
#         PERM_IMPORTANCE   PERM_SD
# Rg_f           1.475645  0.008869
# Tair_f         1.007965  0.008193
# VPD_f          0.535214  0.004569
#
# ## MODEL
# The model was trained on a training set with test size 25.00%.
# - estimator:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=99,
#              n_jobs=-1, num_parallel_tree=None, ...)
# - parameters:  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'feature_weights': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': None, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': None, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 99, 'n_jobs': -1, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# ## MODEL SCORES
# - MAE:  2.354464972058204 (mean absolute error)
# - MedAE:  1.745812363624573 (median absolute error)
# - MSE:  10.493141619548462 (mean squared error)
# - RMSE:  3.239311905258347 (root mean squared error)
# - MAXE:  30.350757015228268 (max error)
# - MAPE:  243055457128.114 (mean absolute percentage error)
# - R2:  0.7166450879804251

# %% [markdown]
# </br>

# %% [markdown]
# ## Attributes
# A lot more information about feature reduction, training and testing, model building and gap-filling is available via the class attributes.

# %%
xgbts.feature_importances_
# Out:
#         PERM_IMPORTANCE   PERM_SD
# Rg_f           1.475645  0.008869
# Tair_f         1.007965  0.008193
# VPD_f          0.535214  0.004569

# %%
xgbts.gapfilling_df_
# Out:
#                      .PREDICTIONS_FULLMODEL  NEE_CUT_REF_orig  .GAP_PREDICTIONS  FLAG_NEE_CUT_REF_orig_gfXG_ISFILLED  NEE_CUT_REF_orig_gfXG .PREDICTIONS_FALLBACK  .GAPFILLED_CUMULATIVE  .PREDICTIONS
# TIMESTAMP_MIDDLE
# 2013-01-01 00:15:00                0.934018               NaN          0.934018                                    1               0.934018                  None               0.934018      0.934018
# 2013-01-01 00:45:00                0.934018               NaN          0.934018                                    1               0.934018                  None               1.868036      0.934018
# 2013-01-01 01:15:00                0.934018               NaN          0.934018                                    1               0.934018                  None               2.802054      0.934018
# 2013-01-01 01:45:00                0.934018             0.538               NaN                                    0               0.538000                  None               3.340054      0.934018
# 2013-01-01 02:15:00                1.141467               NaN          1.141467                                    1               1.141467                  None               4.481521      1.141467
# ...                                     ...               ...               ...                                  ...                    ...                   ...                    ...           ...
# 2022-12-31 21:45:00                2.483982               NaN          2.483982                                    1               2.483982                  None          -77770.442364      2.483982
# 2022-12-31 22:15:00                2.860891             3.518               NaN                                    0               3.518000                  None          -77766.924364      2.860891
# 2022-12-31 22:45:00                3.422467               NaN          3.422467                                    1               3.422467                  None          -77763.501898      3.422467
# 2022-12-31 23:15:00                3.312062               NaN          3.312062                                    1               3.312062                  None          -77760.189836      3.312062
# 2022-12-31 23:45:00                3.145486               NaN          3.145486                                    1               3.145486                  None          -77757.044350      3.145486
#
# [175296 rows x 8 columns]

# %%
xgbts.model_
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=99,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
xgbts.accepted_features_
# Out:
# ['Rg_f', 'Tair_f', 'VPD_f']

# %%
xgbts.rejected_features_
# Out:
# 'None.'

# %%
xgbts.scores_
# Out:
# {'mae': 2.354464972058204,
#  'medae': np.float64(1.745812363624573),
#  'mse': 10.493141619548462,
#  'rmse': 3.239311905258347,
#  'mape': 243055457128.11444,
#  'maxe': np.float64(30.350757015228268),
#  'r2': 0.7166450879804251}

# %% [markdown]
# </br>

# %% [markdown]
# ## Result

# %%
gapfilled = xgbts.get_gapfilled_target()
gapfilled
# Out:
# TIMESTAMP_MIDDLE
# 2013-01-01 00:15:00    0.934018
# 2013-01-01 00:45:00    0.934018
# 2013-01-01 01:15:00    0.934018
# 2013-01-01 01:45:00    0.538000
# 2013-01-01 02:15:00    1.141467
#                          ...
# 2022-12-31 21:45:00    2.483982
# 2022-12-31 22:15:00    3.518000
# 2022-12-31 22:45:00    3.422467
# 2022-12-31 23:15:00    3.312062
# 2022-12-31 23:45:00    3.145486
# Freq: 30min, Name: NEE_CUT_REF_orig_gfXG, Length: 175296, dtype: float64

# %%
flag = xgbts.get_flag()
flag
# Out:
# TIMESTAMP_MIDDLE
# 2013-01-01 00:15:00    1
# 2013-01-01 00:45:00    1
# 2013-01-01 01:15:00    1
# 2013-01-01 01:45:00    0
# 2013-01-01 02:15:00    1
#                       ..
# 2022-12-31 21:45:00    1
# 2022-12-31 22:15:00    0
# 2022-12-31 22:45:00    1
# 2022-12-31 23:15:00    1
# 2022-12-31 23:45:00    1
# Freq: 30min, Name: FLAG_NEE_CUT_REF_orig_gfXG_ISFILLED, Length: 175296, dtype: int64

# %%
gapfilling_df = xgbts.gapfilling_df_
gapfilling_df
# Out:
#                      .PREDICTIONS_FULLMODEL  NEE_CUT_REF_orig  .GAP_PREDICTIONS  FLAG_NEE_CUT_REF_orig_gfXG_ISFILLED  NEE_CUT_REF_orig_gfXG .PREDICTIONS_FALLBACK  .GAPFILLED_CUMULATIVE  .PREDICTIONS
# TIMESTAMP_MIDDLE
# 2013-01-01 00:15:00                0.934018               NaN          0.934018                                    1               0.934018                  None               0.934018      0.934018
# 2013-01-01 00:45:00                0.934018               NaN          0.934018                                    1               0.934018                  None               1.868036      0.934018
# 2013-01-01 01:15:00                0.934018               NaN          0.934018                                    1               0.934018                  None               2.802054      0.934018
# 2013-01-01 01:45:00                0.934018             0.538               NaN                                    0               0.538000                  None               3.340054      0.934018
# 2013-01-01 02:15:00                1.141467               NaN          1.141467                                    1               1.141467                  None               4.481521      1.141467
# ...                                     ...               ...               ...                                  ...                    ...                   ...                    ...           ...
# 2022-12-31 21:45:00                2.483982               NaN          2.483982                                    1               2.483982                  None          -77770.442364      2.483982
# 2022-12-31 22:15:00                2.860891             3.518               NaN                                    0               3.518000                  None          -77766.924364      2.860891
# 2022-12-31 22:45:00                3.422467               NaN          3.422467                                    1               3.422467                  None          -77763.501898      3.422467
# 2022-12-31 23:15:00                3.312062               NaN          3.312062                                    1               3.312062                  None          -77760.189836      3.312062
# 2022-12-31 23:45:00                3.145486               NaN          3.145486                                    1               3.145486                  None          -77757.044350      3.145486
#
# [175296 rows x 8 columns]

# %% [markdown]
# </br>

# %% [markdown]
# ## Plot

# %%
fig, axs = plt.subplots(ncols=2, figsize=(16, 9))
HeatmapDateTime(series=df[TARGET_COL], ax=axs[0]).plot()
HeatmapDateTime(series=gapfilled, ax=axs[1]).plot()

# %%
TimeSeries(gapfilled.cumsum()).plot()

# %% [markdown]
# </br>

# %% [markdown]
# # **End of notebook**
# Congratulations, you reached the end of this notebook! Before you go let's store your finish time.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2026-01-12 21:58:11
