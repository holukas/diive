# %% [markdown]
# Comparison to code from the old meteoscreening tool

# %%
import numpy as np

# %%
# example G
param0 = [16.3399, 0]
param1 = [16.5289, 0]
value = 5
value = (value - param0[1]) / param0[0]
np.polyval(param1, value)
# Out:
# 5.057833891272285

# %%
5 / 16.3399 * 16.5289
# Out:
# 5.057833891272285

# %%
f = 16.5289 / 16.3399
f
# Out:
# 1.0115667782544568

# %%
value = 5 
value * f
# Out:
# 5.057833891272284

# %%
# example PREC
param0 = [1, 0]
param1 = [1.317, 0]
value = 2
value = (value - param0[1]) / param0[0]
np.polyval(param1, value)
# Out:
# 2.634

# %%
# PREC comment from fieldbook OE2 04.06.2007
2 / 1.6 * 1.317
# Out:
# 1.64625

# %%
# example TS
param0 = [1, 0]
param1 = [1, 52]
value = -39
value = (value - param0[1]) / param0[0]
np.polyval(param1, value)
# Out:
# 13.0

# %%
-39 + 52
# Out:
# 13

# %%
# example SWC to %
param0 = [1, 0]
param1 = [100, 0]
value = 0.34
value = (value - param0[1]) / param0[0]
np.polyval(param1, value)
# Out:
# 34.0

# %%
# example SW_IN
param0 = [16.2602,0]
param1 = [183.486,0]
value_orig = -1
value = (value_orig - param0[1]) / param0[0]
result = np.polyval(param1, value)
result = result * -1
result
# Out:
# 11.284363045964993

# %%
value / value_orig
# Out:
# 0.06149985855032533

# %%
factor = 0.06149985855032533 * 183.486 * -1
factor
# Out:
# -11.284363045964993

# %%
1 / 16.2602
# Out:
# 0.06149985855032533

# %%
-105 * factor
# Out:
# 1184.8581198263241

# %%
(-105 / 16.2602) * 183.486 * -1
# Out:
# 1184.8581198263241
