# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Daily Correlation
# </b>
# </span>

# %% [markdown]
# ---
# **Notebook version**: `1` (18 Mar 2024)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %% [markdown]
# # **Description**

# %% [markdown]
# - Calculate daily correlation between two time series.
# - In example (1), the daily correlation between observed global radiation `Rg_f` (observed value) and potential radiation `SW_IN_POT` (calculated value) is investigated.
#     - Both variables are expected to be highly correlated.
#     - If correlations are low this could be indivative of problems with the sensor or other issues, e.g., a timestamp shift.
# - In example (2), the daily correlation between observed global radiation `Rg_f` (observed value) and air temperature `Tair_f` (observed value) is investigated.

# %% [markdown]
# </br>

# %% [markdown]
# # **Imports**

# %%
import importlib.metadata
import warnings
from datetime import datetime

warnings.filterwarnings('ignore')
from diive.pkgs.analyses.correlation import daily_correlation
from diive.configs.exampledata import load_exampledata_parquet  # Example data
from diive.pkgs.createvar.potentialradiation import potrad  # Function to calculate potential radiation

version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
# Out:
# diive version: v0.85.0

# %%
# help(daily_correlation)

# %% [markdown]
# </br>

# %% [markdown]
# # **Load example data**

# %%
data_df = load_exampledata_parquet()
data_df = data_df.loc[data_df.index.year == 2022].copy()  # Use only year 2022
data_df
# Out:
# Loaded .parquet file L:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\configs\exampledata\exampledata_PARQUET_CH-DAV_FP2022.5_2013-2022_ID20230206154316_30MIN.parquet (0.042 seconds).
#     --> Detected time resolution of <30 * Minutes> / 30min
#                       ET_f  GPP_CUT_16_f  GPP_CUT_84_f  GPP_CUT_REF_f  GPP_DT_CUT_16  GPP_DT_CUT_84  GPP_DT_CUT_REF    LE_f  LE_orig    LW_IN  NEE_CUT_16_f  NEE_CUT_16_orig  NEE_CUT_84_f  NEE_CUT_84_orig  NEE_CUT_REF_f  ...  Reco_CUT_84  Reco_CUT_REF  Reco_DT_CUT_16  Reco_DT_CUT_84  Reco_DT_CUT_REF  Reco_DT_CUT_REF_SD  Rg_f  Rg_orig      RH  SWC_FF0_0.15_1  Tair_f  Tair_orig  Ustar_CUT_REF_Thres  VPD_f  VPD_orig
# TIMESTAMP_MIDDLE                                                                                                                                                                                                            ...
# 2022-01-01 00:15:00  0.176         1.033         0.591          0.816            0.0            0.0             0.0   7.909      NaN  240.852        -0.481              NaN         0.299              NaN         -0.216  ...        0.890         0.600           1.350           2.148            2.222               5.191   0.0      0.0  42.030          27.288   3.977      3.977                0.288  4.709     4.709
# 2022-01-01 00:45:00  0.170         1.033         0.593          0.817            0.0            0.0             0.0   7.653      NaN  240.912        -0.481              NaN         0.299              NaN         -0.216  ...        0.892         0.601           1.362           2.149            2.244               5.206   0.0      0.0  41.527          27.288   4.027      4.027                0.288  4.767     4.767
# 2022-01-01 01:15:00  0.151         1.015         0.558          0.797            0.0            0.0             0.0   6.790      NaN  240.549        -0.481              NaN         0.299              NaN         -0.216  ...        0.857         0.581           1.320           2.075            2.180               5.024   0.0      0.0  43.363          27.288   3.603      3.603                0.288  4.481     4.481
# 2022-01-01 01:45:00  0.140         0.782         0.527          0.779            0.0            0.0             0.0   6.279      NaN  239.717        -0.264              NaN         0.299              NaN         -0.216  ...        0.826         0.563           1.282           2.008            2.122               4.860   0.0      0.0  45.397          27.288   3.213      3.213                0.288  4.203     4.203
# 2022-01-01 02:15:00  0.134         0.777         0.517          0.773            0.0            0.0             0.0   6.007      NaN  239.508        -0.264              NaN         0.299              NaN         -0.216  ...        0.816         0.557           1.275           1.984            2.113               4.807   0.0      0.0  45.967          27.290   3.097      3.097                0.288  4.124     4.124
# ...                    ...           ...           ...            ...            ...            ...             ...     ...      ...      ...           ...              ...           ...              ...            ...  ...          ...           ...             ...             ...              ...                 ...   ...      ...     ...             ...     ...        ...                  ...    ...       ...
# 2022-12-31 21:45:00 -0.016         0.373         0.203          0.600            0.0            0.0             0.0  -0.735   -0.735  230.499         0.629              NaN         1.253              NaN          1.224  ...        1.456         1.824           2.568           1.221            1.032               0.759   0.0      0.0  71.790          19.572   3.463      3.463                0.288  2.210     2.210
# 2022-12-31 22:15:00  0.105        -2.379         0.894         -1.433            0.0            0.0             0.0   4.724    4.724  231.788         3.518            3.518         0.803              NaN          3.518  ...        1.697         2.085           2.959           1.356            1.174               0.838   0.0      0.0  62.627          19.577   5.283      5.283                0.288  3.327     3.327
# 2022-12-31 22:45:00  0.220        -0.515         0.926         -0.305            0.0            0.0             0.0   9.840      NaN  237.303         1.673              NaN         0.803              NaN          2.424  ...        1.729         2.119           3.038           1.367            1.199               0.857   0.0      0.0  61.747          19.589   5.537      5.537                0.288  3.467     3.467
# 2022-12-31 23:15:00  0.059         0.847         0.843          1.014            0.0            0.0             0.0   2.653    2.653  251.268         0.266              NaN         0.803              NaN          1.017  ...        1.646         2.031           2.942           1.311            1.159               0.843   0.0      0.0  65.427          19.609   4.963      4.963                0.288  3.010     3.010
# 2022-12-31 23:45:00  0.328        -1.049         0.754         -0.023            0.0            0.0             0.0  14.700   14.700  244.312         2.281              NaN         1.104              NaN          2.281  ...        1.859         2.258           3.298           1.426            1.286               0.916   0.0      0.0  59.667          19.631   6.490      6.490                0.288  3.905     3.905
#
# [17520 rows x 37 columns]

# %%
rg_series = data_df['Rg_f'].copy()  # Observed radiation time series for example (1) and (2)
ta_series = data_df['Tair_f'].copy()  # Observed air temperature time series for example (2)
nee_series = data_df[
    'NEE_CUT_REF_f'].copy()  # Observed net ecosystem exhange of CO2 time series from eddy covariance measurements for example (3)
print("Time series of global radiation in W m-2:")
display(rg_series)
print("\n\nTime series of air temperature in °C:")
display(ta_series)
print("\n\nTime series of net ecosystem exchange of CO2 in µmol CO2 m-2 s-1:")
display(nee_series)
# Out:
# Time series of global radiation in W m-2:
# TIMESTAMP_MIDDLE
# 2022-01-01 00:15:00    0.0
# 2022-01-01 00:45:00    0.0
# 2022-01-01 01:15:00    0.0
# 2022-01-01 01:45:00    0.0
# 2022-01-01 02:15:00    0.0
#                       ...
# 2022-12-31 21:45:00    0.0
# 2022-12-31 22:15:00    0.0
# 2022-12-31 22:45:00    0.0
# 2022-12-31 23:15:00    0.0
# 2022-12-31 23:45:00    0.0
# Freq: 30min, Name: Rg_f, Length: 17520, dtype: float64
# Time series of air temperature in °C:
# TIMESTAMP_MIDDLE
# 2022-01-01 00:15:00    3.977
# 2022-01-01 00:45:00    4.027
# 2022-01-01 01:15:00    3.603
# 2022-01-01 01:45:00    3.213
# 2022-01-01 02:15:00    3.097
#                        ...
# 2022-12-31 21:45:00    3.463
# 2022-12-31 22:15:00    5.283
# 2022-12-31 22:45:00    5.537
# 2022-12-31 23:15:00    4.963
# 2022-12-31 23:45:00    6.490
# Freq: 30min, Name: Tair_f, Length: 17520, dtype: float64
# Time series of net ecosystem exchange of CO2 in µmol CO2 m-2 s-1:
# TIMESTAMP_MIDDLE
# 2022-01-01 00:15:00   -0.216
# 2022-01-01 00:45:00   -0.216
# 2022-01-01 01:15:00   -0.216
# 2022-01-01 01:45:00   -0.216
# 2022-01-01 02:15:00   -0.216
#                        ...
# 2022-12-31 21:45:00    1.224
# 2022-12-31 22:15:00    3.518
# 2022-12-31 22:45:00    2.424
# 2022-12-31 23:15:00    1.017
# 2022-12-31 23:45:00    2.281
# Freq: 30min, Name: NEE_CUT_REF_f, Length: 17520, dtype: float64

# %%
# Calculate potential radiation SW_IN_POT to use as reference in example (1)
reference = potrad(timestamp_index=rg_series.index,
                   lat=47.286417,
                   lon=7.733750,
                   utc_offset=1)
reference
# Out:
# TIMESTAMP_MIDDLE
# 2022-01-01 00:15:00    0.0
# 2022-01-01 00:45:00    0.0
# 2022-01-01 01:15:00    0.0
# 2022-01-01 01:45:00    0.0
# 2022-01-01 02:15:00    0.0
#                       ...
# 2022-12-31 21:45:00    0.0
# 2022-12-31 22:15:00    0.0
# 2022-12-31 22:45:00    0.0
# 2022-12-31 23:15:00    0.0
# 2022-12-31 23:45:00    0.0
# Freq: 30min, Name: SW_IN_POT, Length: 17520, dtype: float64

# %% [markdown]
# </br>

# %% [markdown]
# # (1) **Calculate daily correlation between `Rg_f` and `SW_IN_POT`**

# %%
daycorrs = daily_correlation(
    s1=rg_series,
    s2=reference,
    mincorr=0.8,
    showplot=True
)

# %%
# All daily correlations
daycorrs
# Out:
# DATE
# 2022-01-01    0.967678
# 2022-01-02    0.954463
# 2022-01-03    0.955140
# 2022-01-04    0.962414
# 2022-01-05    0.987641
#                 ...
# 2022-12-27    0.960270
# 2022-12-28    0.936301
# 2022-12-29    0.967984
# 2022-12-30    0.920200
# 2022-12-31    0.962476
# Freq: D, Name: daycorrs, Length: 365, dtype: float64

# %% [markdown]
# </br>

# %% [markdown]
# # (2) **Calculate daily correlation between `Tair_f` and `Rg_f`**

# %%
daycorrs = daily_correlation(
    s1=ta_series,
    s2=rg_series
)

# %%
# All daily correlations
daycorrs
# Out:
# DATE
# 2022-01-01    0.854452
# 2022-01-02    0.828606
# 2022-01-03    0.754225
# 2022-01-04    0.729151
# 2022-01-05    0.020350
#                 ...
# 2022-12-27    0.270953
# 2022-12-28    0.578541
# 2022-12-29    0.475528
# 2022-12-30    0.294125
# 2022-12-31    0.705969
# Freq: D, Name: daycorrs, Length: 365, dtype: float64

# %% [markdown]
# </br>

# %% [markdown]
# # (3) **Calculate daily correlation between `Tair_f` and `NEE_CUT_REF_f`**

# %%
daycorrs = daily_correlation(
    s1=ta_series,
    s2=nee_series,
    showplot=False
)

# %%
# All daily correlations
daycorrs
# Out:
# DATE
# 2022-01-01    0.588741
# 2022-01-02    0.206918
# 2022-01-03   -0.066644
# 2022-01-04    0.095609
# 2022-01-05   -0.237885
#                 ...
# 2022-12-27   -0.304999
# 2022-12-28   -0.248761
# 2022-12-29   -0.118126
# 2022-12-30   -0.291619
# 2022-12-31   -0.370086
# Freq: D, Name: daycorrs, Length: 365, dtype: float64

# %%
daycorrs.plot();

# %% [markdown]
# </br>

# %% [markdown]
# # **End of notebook**

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished {dt_string}")
# Out:
# Finished 2025-01-23 12:40:50
