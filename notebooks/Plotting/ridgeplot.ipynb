# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Ridgeplot
# </b>
# </span>

# %% [markdown]
# ---
# **Notebook version**: `1` (17 Mar 2025)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %% [markdown]
# # **Description**

# %% [markdown]
# - Make a ridge plot from time series data
# - This example uses half-hourly air temperature data from 2019

# %% [markdown]
# </br>

# %% [markdown]
# # **Imports**

# %%
import importlib.metadata
from datetime import datetime
import warnings
warnings.simplefilter("ignore", UserWarning)
import diive as dv
from diive.configs.exampledata import load_exampledata_parquet

version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
# Out:
# diive version: v0.86.0

# %% [markdown]
# </br>

# %% [markdown]
# # **Load example data**

# %%
df = load_exampledata_parquet()
ta = df['Tair_f'].copy()
ta
# Out:
# Loaded .parquet file F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\configs\exampledata\exampledata_PARQUET_CH-DAV_FP2022.5_2013-2022_ID20230206154316_30MIN.parquet (0.049 seconds).
#     --> Detected time resolution of <30 * Minutes> / 30min
# TIMESTAMP_MIDDLE
# 2013-01-01 00:15:00   -1.618
# 2013-01-01 00:45:00   -1.630
# 2013-01-01 01:15:00   -1.644
# 2013-01-01 01:45:00   -1.657
# 2013-01-01 02:15:00   -0.567
#                        ...
# 2022-12-31 21:45:00    3.463
# 2022-12-31 22:15:00    5.283
# 2022-12-31 22:45:00    5.537
# 2022-12-31 23:15:00    4.963
# 2022-12-31 23:45:00    6.490
# Freq: 30min, Name: Tair_f, Length: 175296, dtype: float64

# %% [markdown]
# </br>

# %% [markdown]
# # **Ridge plot per month**

# %% [markdown]
# ## Example data for one year (2019)

# %%
series = ta.loc[ta.index.year == 2019].copy()
series
# Out:
# TIMESTAMP_MIDDLE
# 2019-01-01 00:15:00   -3.380
# 2019-01-01 00:45:00   -3.357
# 2019-01-01 01:15:00   -3.607
# 2019-01-01 01:45:00   -3.890
# 2019-01-01 02:15:00   -4.003
#                        ...
# 2019-12-31 21:45:00   -2.440
# 2019-12-31 22:15:00   -2.447
# 2019-12-31 22:45:00   -2.455
# 2019-12-31 23:15:00   -2.463
# 2019-12-31 23:45:00   -2.470
# Freq: 30min, Name: Tair_f, Length: 17520, dtype: float64

# %% [markdown]
# ## Make plot

# %%
rp = dv.ridgeplot(series=series)  # Init RidgePlotTS instance
rp.per_month()

# %% [markdown]
# </br>

# %% [markdown]
# # **Ridge plot per year**

# %% [markdown]
# ## Example data for 10 years (2013-2022)

# %%
ta
# Out:
# TIMESTAMP_MIDDLE
# 2013-01-01 00:15:00   -1.618
# 2013-01-01 00:45:00   -1.630
# 2013-01-01 01:15:00   -1.644
# 2013-01-01 01:45:00   -1.657
# 2013-01-01 02:15:00   -0.567
#                        ...
# 2022-12-31 21:45:00    3.463
# 2022-12-31 22:15:00    5.283
# 2022-12-31 22:45:00    5.537
# 2022-12-31 23:15:00    4.963
# 2022-12-31 23:45:00    6.490
# Freq: 30min, Name: Tair_f, Length: 175296, dtype: float64

# %% [markdown]
# ## Make plot

# %%
rp = dv.ridgeplot(series=ta)
rp.per_year()

# %% [markdown]
# </br>

# %% [markdown]
# # **Ridge plot per week**

# %% [markdown]
# ## Example data for one year (2019)

# %%
series = ta.loc[ta.index.year == 2019].copy()
series
# Out:
# TIMESTAMP_MIDDLE
# 2019-01-01 00:15:00   -3.380
# 2019-01-01 00:45:00   -3.357
# 2019-01-01 01:15:00   -3.607
# 2019-01-01 01:45:00   -3.890
# 2019-01-01 02:15:00   -4.003
#                        ...
# 2019-12-31 21:45:00   -2.440
# 2019-12-31 22:15:00   -2.447
# 2019-12-31 22:45:00   -2.455
# 2019-12-31 23:15:00   -2.463
# 2019-12-31 23:45:00   -2.470
# Freq: 30min, Name: Tair_f, Length: 17520, dtype: float64

# %% [markdown]
# ## Make plot

# %%
rp = dv.ridgeplot(series=series)
rp.per_week()

# %% [markdown]
# </br>

# %% [markdown]
# # **Ridge plot per month** with full parameters

# %% [markdown]
# ## Example data for one year (2019)

# %%
series = ta.loc[ta.index.year == 2019].copy()
series
# Out:
# TIMESTAMP_MIDDLE
# 2019-01-01 00:15:00   -3.380
# 2019-01-01 00:45:00   -3.357
# 2019-01-01 01:15:00   -3.607
# 2019-01-01 01:45:00   -3.890
# 2019-01-01 02:15:00   -4.003
#                        ...
# 2019-12-31 21:45:00   -2.440
# 2019-12-31 22:15:00   -2.447
# 2019-12-31 22:45:00   -2.455
# 2019-12-31 23:15:00   -2.463
# 2019-12-31 23:45:00   -2.470
# Freq: 30min, Name: Tair_f, Length: 17520, dtype: float64

# %% [markdown]
# ## Make plot

# %%
rp = dv.ridgeplot(series=series)
rp.per_month(
    xlim=None,  # min/max as list
    ylim=None,  # min/max as list
    hspace=-0.5,  # overlap between months
    xlabel=r'Air temperature (°C)',    
    fig_width=8,
    fig_height=10,
    shade_percentile= 0.5,
    show_mean_line=False,
    fig_title= "Air temperatures per month (2019)",
    fig_dpi=72,
    showplot=True,
    ascending=False
)

# %% [markdown]
# </br>

# %% [markdown]
# # **End of notebook**

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished {dt_string}")
# Out:
# Finished 2025-03-17 19:28:18
