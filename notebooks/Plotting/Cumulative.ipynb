# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Cumulatives per year
# </b>
# </span>

# %% [markdown]
# ---
# **Notebook version**: `1` (16 Sep 2024)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %% [markdown]
# # **Description**

# %% [markdown]
# - Plot cumulative sum across all data

# %% [markdown]
# </br>

# %% [markdown]
# # **Imports**

# %%
import importlib.metadata
import warnings
from datetime import datetime

warnings.simplefilter("ignore", UserWarning)
from diive.configs.exampledata import load_exampledata_parquet
from diive.core.plotting.cumulative import Cumulative

version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
# Out:
# diive version: v0.83.2

# %% [markdown]
# </br>

# %% [markdown]
# # **Load example data**

# %%
df_orig = load_exampledata_parquet()
df = df_orig[['NEE_CUT_16_f', 'NEE_CUT_REF_f', 'NEE_CUT_84_f']].copy()
df.plot(x_compat=True, subplots=True);
# Out:
# Loaded .parquet file L:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\configs\exampledata\exampledata_PARQUET_CH-DAV_FP2022.5_2013-2022_ID20230206154316_30MIN.parquet (0.050 seconds). Detected time resolution of <30 * Minutes> / 30min

# %% [markdown]
# </br>

# %% [markdown]
# # **Plot cumulative sum for each column**

# %%
# The series is the CO2 ecosystem flux, convert to more approriate units for yearly sums
df = df.multiply(0.02161926)  # Convert units: umol CO2 m-2 s-1 --> g C m-2 30min-1
series_units = r'($\mathrm{gC\ m^{-2}}$)'

# %%
cumu = Cumulative(
    df=df,
    units=series_units,
    start_year=2015,
    end_year=2020)
cumu.plot()

# %%
ax = cumu.get_ax()
ax
# Out:
# <Axes: xlabel='Date', ylabel='Cumulative  ($\\mathrm{gC\\ m^{-2}}$)'>

# %% [markdown]
# </br>

# %% [markdown]
# # **End of notebook**

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished {dt_string}")
# Out:
# Finished 2024-10-25 00:14:11
