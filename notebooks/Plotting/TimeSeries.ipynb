# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Simple time series plot
# </b>
# </span>

# %% [markdown]
# ---
# **Notebook version**: `1` (25 Oct 2023)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %% [markdown]
# # **Imports**

# %%
import importlib.metadata
from datetime import datetime
from diive.core.plotting.timeseries import TimeSeries
from diive.configs.exampledata import load_exampledata_parquet

version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
# Out:
# diive version: v0.74.0

# %% [markdown]
# </br>

# %% [markdown]
# # **Load data**

# %%
df = load_exampledata_parquet()
df
# Out:
# Loaded .parquet file F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\configs\exampledata\exampledata_PARQUET_CH-DAV_FP2022.5_2013-2022_ID20230206154316_30MIN.parquet (0.059 seconds). Detected time resolution of <30 * Minutes> / 30min
#                       ET_f  GPP_CUT_16_f  GPP_CUT_84_f  GPP_CUT_REF_f  GPP_DT_CUT_16  GPP_DT_CUT_84  ...  SWC_FF0_0.15_1  Tair_f  Tair_orig  Ustar_CUT_REF_Thres  VPD_f  VPD_orig
# TIMESTAMP_MIDDLE                                                                                     ...
# 2013-01-01 00:15:00  0.290         0.510        -0.082          0.705            0.0            0.0  ...          34.977  -1.618     -1.618                0.288  1.339     1.339
# 2013-01-01 00:45:00  0.290         0.512        -0.084          0.708            0.0            0.0  ...          34.977  -1.630     -1.630                0.288  1.337     1.337
# 2013-01-01 01:15:00  0.290         0.514        -0.086          0.710            0.0            0.0  ...          34.971  -1.644     -1.644                0.288  1.335     1.335
# 2013-01-01 01:45:00  0.290         1.354        -0.088          1.771            0.0            0.0  ...          34.975  -1.657     -1.657                0.288  1.332     1.332
# 2013-01-01 02:15:00  0.377         0.545        -0.080          0.797            0.0            0.0  ...          34.967  -0.567     -0.567                0.288  3.545     3.545
# ...                    ...           ...           ...            ...            ...            ...  ...             ...     ...        ...                  ...    ...       ...
# 2022-12-31 21:45:00 -0.016         0.373         0.203          0.600            0.0            0.0  ...          19.572   3.463      3.463                0.288  2.210     2.210
# 2022-12-31 22:15:00  0.105        -2.379         0.894         -1.433            0.0            0.0  ...          19.577   5.283      5.283                0.288  3.327     3.327
# 2022-12-31 22:45:00  0.220        -0.515         0.926         -0.305            0.0            0.0  ...          19.589   5.537      5.537                0.288  3.467     3.467
# 2022-12-31 23:15:00  0.059         0.847         0.843          1.014            0.0            0.0  ...          19.609   4.963      4.963                0.288  3.010     3.010
# 2022-12-31 23:45:00  0.328        -1.049         0.754         -0.023            0.0            0.0  ...          19.631   6.490      6.490                0.288  3.905     3.905
#
# [175296 rows x 37 columns]

# %%
series = df['NEE_CUT_REF_orig'].copy()
series
# Out:
# TIMESTAMP_MIDDLE
# 2013-01-01 00:15:00      NaN
# 2013-01-01 00:45:00      NaN
# 2013-01-01 01:15:00      NaN
# 2013-01-01 01:45:00    0.538
# 2013-01-01 02:15:00      NaN
#                        ...
# 2022-12-31 21:45:00      NaN
# 2022-12-31 22:15:00    3.518
# 2022-12-31 22:45:00      NaN
# 2022-12-31 23:15:00      NaN
# 2022-12-31 23:45:00      NaN
# Freq: 30min, Name: NEE_CUT_REF_orig, Length: 175296, dtype: float64

# %% [markdown]
# </br>

# %% [markdown]
# # **Plot**
# - static of interactive (in notebooks)

# %%
# TimeSeries(series=series).plot_interactive()
TimeSeries(series=series).plot()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\timeseries.py:136: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()

# %% [markdown]
# </br>

# %% [markdown]
# # **FINISH**
# Congratulations, you reached the end of this notebook! Before you go let's store your finish time.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2024-04-20 16:15:02
