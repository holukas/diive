# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)
# # **Convert EddyPro _fluxnet_ output files for upload to FLUXNET database**
#
# **Notebook creation date**: 24 Apr 2023
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)
# ---
# Example notebook for class `ConvertEddyProFluxnetFileForUpload` in `diive.pkgs.formats.fluxnet` of the time series processing library `diive`.

# %% [markdown]
# # Background

# %% [markdown]
# - Eddypro outputs `_fluxnet_` files
# - The files cannot be directly uploaded to the FLUXNET database
# - The class `ConvertEddyProFluxnetFileForUpload` helps in formatting the files to comply with FLUXNET requirements for data sharing
#
# ## From docstring
#
# Helper class to convert EddyPro _fluxnet_ output files to the file
# format required for data upload (data sharing) to FLUXNET
#
# The class does the following:
# - Search source folder for _fluxnet_ files
# - Load data from all found files and store in dataframe
# - Make subset that contains required variables
# - Set missing values to FLUXNET format (-9999)
# - Rename variables by adding the FLUXNET suffix (_1_1_1)
# - Insert two timestamp columns denoting START and END of averaging interval
# - Format the two timestamp columns to FLUXNET format YYYYMMDDhhmm
# - Save data from dataframe to yearly files

# %% [markdown]
# # Imports

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from diive.pkgs.formats.fluxnet import ConvertEddyProFluxnetFileForUpload
from diive.core.plotting.heatmap_datetime import HeatmapDateTime
# Out:
# C:\Users\nopan\AppData\Local\pypoetry\Cache\virtualenvs\diive-wQ6jAUAf-py3.9\lib\site-packages\statsmodels\compat\pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %% [markdown]
# # Source and output folders

# %%
SOURCE = r"L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files"
OUTDIR = r"L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload"

# %% [markdown]
# # Merge files, format data and save yearly files

# %%
con = ConvertEddyProFluxnetFileForUpload(
    site='CH-FRU',
    sourcedir=SOURCE,
    outdir=OUTDIR,
    limit_n_files=None,
    add_runid=True)
con.run()
# Out:
# Searching for EddyPro _fluxnet_ files in folder L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files ...
#     Found 18 files:
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2005_eddypro_CH-FRU_FR-20230416-191448_fluxnet_2023-04-17T101709_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2006_eddypro_CH-FRU_FR-20230416-190735_fluxnet_2023-04-18T064524_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2007_eddypro_CH-FRU_FR-20230416-190217_fluxnet_2023-04-18T035037_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2008_eddypro_CH-FRU_FR-20230416-185746_fluxnet_2023-04-18T071628_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2009_eddypro_CH-FRU_FR-20230416-185255_fluxnet_2023-04-18T064358_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2010_eddypro_CH-FRU_FR-20230416-184908_fluxnet_2023-04-18T061240_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2011_eddypro_CH-FRU_FR-20230416-175421_fluxnet_2023-04-18T061255_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2012_eddypro_CH-FRU_FR-20230416-174911_fluxnet_2023-04-18T043834_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2013_eddypro_CH-FRU_FR-20230416-143253_fluxnet_2023-04-18T031012_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2014_eddypro_CH-FRU_FR-20230416-142757_fluxnet_2023-04-18T032334_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2015_eddypro_CH-FRU_FR-20230416-142548_fluxnet_2023-04-18T041815_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2016_eddypro_CH-FRU_FR-20230414-122650_fluxnet_2023-04-15T150815_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2017_eddypro_CH-FRU_FR-20230416-142215_fluxnet_2023-04-18T073447_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2018_eddypro_CH-FRU_FR-20230414-121313_fluxnet_2023-04-15T193102_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2019_eddypro_CH-FRU_FR-20230414-121107_fluxnet_2023-04-15T200137_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2020_eddypro_CH-FRU_FR-20230414-120632_fluxnet_2023-04-15T193001_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2021_eddypro_CH-FRU_FR-20230414-120138_fluxnet_2023-04-15T182801_adv.csv
#        --> L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\0-eddypro_fluxnet_files\2022_eddypro_CH-FRU_FR-20230414-115624_fluxnet_2023-04-15T180714_adv.csv
# Reading file 2005_eddypro_CH-FRU_FR-20230416-191448_fluxnet_2023-04-17T101709_adv.csv ...
# Reading file 2006_eddypro_CH-FRU_FR-20230416-190735_fluxnet_2023-04-18T064524_adv.csv ...
# Reading file 2007_eddypro_CH-FRU_FR-20230416-190217_fluxnet_2023-04-18T035037_adv.csv ...
# Reading file 2008_eddypro_CH-FRU_FR-20230416-185746_fluxnet_2023-04-18T071628_adv.csv ...
# Reading file 2009_eddypro_CH-FRU_FR-20230416-185255_fluxnet_2023-04-18T064358_adv.csv ...
# Reading file 2010_eddypro_CH-FRU_FR-20230416-184908_fluxnet_2023-04-18T061240_adv.csv ...
# Reading file 2011_eddypro_CH-FRU_FR-20230416-175421_fluxnet_2023-04-18T061255_adv.csv ...
# Reading file 2012_eddypro_CH-FRU_FR-20230416-174911_fluxnet_2023-04-18T043834_adv.csv ...
# Reading file 2013_eddypro_CH-FRU_FR-20230416-143253_fluxnet_2023-04-18T031012_adv.csv ...
# Reading file 2014_eddypro_CH-FRU_FR-20230416-142757_fluxnet_2023-04-18T032334_adv.csv ...
# Reading file 2015_eddypro_CH-FRU_FR-20230416-142548_fluxnet_2023-04-18T041815_adv.csv ...
# Reading file 2016_eddypro_CH-FRU_FR-20230414-122650_fluxnet_2023-04-15T150815_adv.csv ...
# Reading file 2017_eddypro_CH-FRU_FR-20230416-142215_fluxnet_2023-04-18T073447_adv.csv ...
# Reading file 2018_eddypro_CH-FRU_FR-20230414-121313_fluxnet_2023-04-15T193102_adv.csv ...
# Reading file 2019_eddypro_CH-FRU_FR-20230414-121107_fluxnet_2023-04-15T200137_adv.csv ...
# Reading file 2020_eddypro_CH-FRU_FR-20230414-120632_fluxnet_2023-04-15T193001_adv.csv ...
# Reading file 2021_eddypro_CH-FRU_FR-20230414-120138_fluxnet_2023-04-15T182801_adv.csv ...
# Reading file 2022_eddypro_CH-FRU_FR-20230414-115624_fluxnet_2023-04-15T180714_adv.csv ...
# Found: ['FC', 'FC_SSITC_TEST', 'SC_SINGLE', 'CO2', 'LE', 'LE_SSITC_TEST', 'SLE_SINGLE', 'H2O', 'H', 'H_SSITC_TEST', 'SH_SINGLE', 'USTAR', 'WD', 'WS', 'FETCH_70', 'FETCH_90', 'FETCH_MAX', 'SW_IN_1_1_1', 'TA_1_1_1', 'RH_1_1_1', 'PA_1_1_1', 'LW_IN_1_1_1', 'PPFD_IN_1_1_1']
# Not found: ['G_1_1_1', 'NETRAD_1_1_1', 'TS_1_1_1', 'P_1_1_1', 'SWC_1_1_1']
#
# The following variables have been renamed:
#     RENAMED --> FC was renamed to FC_1_1_1
#     RENAMED --> FC_SSITC_TEST was renamed to FC_SSITC_TEST_1_1_1
#     RENAMED --> SC_SINGLE was renamed to SC_SINGLE_1_1_1
#     RENAMED --> CO2 was renamed to CO2_1_1_1
#     RENAMED --> LE was renamed to LE_1_1_1
#     RENAMED --> LE_SSITC_TEST was renamed to LE_SSITC_TEST_1_1_1
#     RENAMED --> SLE_SINGLE was renamed to SLE_SINGLE_1_1_1
#     RENAMED --> H2O was renamed to H2O_1_1_1
#     RENAMED --> H was renamed to H_1_1_1
#     RENAMED --> H_SSITC_TEST was renamed to H_SSITC_TEST_1_1_1
#     RENAMED --> SH_SINGLE was renamed to SH_SINGLE_1_1_1
#     RENAMED --> USTAR was renamed to USTAR_1_1_1
#     RENAMED --> WD was renamed to WD_1_1_1
#     RENAMED --> WS was renamed to WS_1_1_1
#     RENAMED --> FETCH_70 was renamed to FETCH_70_1_1_1
#     RENAMED --> FETCH_90 was renamed to FETCH_90_1_1_1
#     RENAMED --> FETCH_MAX was renamed to FETCH_MAX_1_1_1
#
# The following variables have not been renamed:
#     NOT RENAMED --> SW_IN_1_1_1 was not renamed
#     NOT RENAMED --> TA_1_1_1 was not renamed
#     NOT RENAMED --> RH_1_1_1 was not renamed
#     NOT RENAMED --> PA_1_1_1 was not renamed
#     NOT RENAMED --> LW_IN_1_1_1 was not renamed
#     NOT RENAMED --> PPFD_IN_1_1_1 was not renamed
#
# Adding new timestamp column TIMESTAMP_END to show end of averaging period ...
#     ++Added new timestamp column TIMESTAMP_END:
#         first date: 2005-07-05 09:00:00
#         last date:  2023-01-01 01:00:00
#     The timestamp index was not changed:
#         first date: 2005-07-05 08:45:00
#         last date:  2023-01-01 00:45:00
#
# Adding new timestamp column TIMESTAMP_START to show start of averaging period ...
#     ++Added new timestamp column TIMESTAMP_START:
#         first date: 2005-07-05 08:30:00
#         last date:  2023-01-01 00:30:00
#     The timestamp index was not changed:
#         first date: 2005-07-05 08:45:00
#         last date:  2023-01-01 00:45:00
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2005_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2006_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2007_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2008_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2009_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2010_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2011_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2012_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2013_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2014_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2015_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2016_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2017_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2018_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2019_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2020_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2021_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2022_fluxes_meteo_20230424.csv.
#
# --> Saved file L:\Sync\luhk_work\_current\Level-1_results_for_FLUXNET_upload\1-formatted_for_upload\CH-FRU_2023_fluxes_meteo_20230424.csv.

# %% [markdown]
# # Results

# %% [markdown]
# - The merged file data from all files can be directly returned with `.get_data()`
# - Note that the dataframe below does not show exactly how the data look like in the formatted data files, but how data were stored in `diive`, hence the timestamp index `TIMESTAMP_MIDDLE`
# - The yearly files do not contain the timestamp index `TIMESTAMP_MIDDLE`

# %%
data_fluxnet = con.get_data()
data_fluxnet
# Out:
#                     TIMESTAMP_START TIMESTAMP_END  FC_1_1_1  FC_SSITC_TEST_1_1_1  SC_SINGLE_1_1_1  CO2_1_1_1  LE_1_1_1  LE_SSITC_TEST_1_1_1  SLE_SINGLE_1_1_1  H2O_1_1_1    H_1_1_1  H_SSITC_TEST_1_1_1  SH_SINGLE_1_1_1  USTAR_1_1_1  WD_1_1_1  WS_1_1_1  FETCH_70_1_1_1  FETCH_90_1_1_1  FETCH_MAX_1_1_1  SW_IN_1_1_1    TA_1_1_1   RH_1_1_1  PA_1_1_1  LW_IN_1_1_1  PPFD_IN_1_1_1
# TIMESTAMP_MIDDLE
# 2005-07-05 08:45:00    200507050830  200507050900 -1.451100                  1.0     -9999.000000    433.936  0.325157                  1.0      -9999.000000   13.27570   0.959042                 1.0     -9999.000000     0.004104  113.1020  0.015840         -9999.0         -9999.0          -9999.0      -9999.0 -9999.00000 -9999.0000   -9999.0    -9999.000        -9999.0
# 2005-07-05 09:15:00    200507050900  200507050930  0.208211                  2.0         0.755107    448.802  0.069278                  2.0         -0.641656   12.98790   0.173378                 1.0        -1.185400     0.006308  125.1690  0.018193         -9999.0         -9999.0          -9999.0      -9999.0 -9999.00000 -9999.0000   -9999.0    -9999.000        -9999.0
# 2005-07-05 09:45:00    200507050930  200507051000 -0.381118                  2.0        -1.900810    411.437 -0.108938                  2.0         -0.697851   12.67560   1.252460                 1.0        -0.629611     0.006090  131.1880  0.015613         -9999.0         -9999.0          -9999.0      -9999.0 -9999.00000 -9999.0000   -9999.0    -9999.000        -9999.0
# 2005-07-05 10:15:00    200507051000  200507051030  0.119783                  1.0        -0.311462    405.315 -0.064693                  1.0         -0.486056   12.45800   0.078104                 1.0         0.000896     0.007233  133.9610  0.017642         -9999.0         -9999.0          -9999.0      -9999.0 -9999.00000 -9999.0000   -9999.0    -9999.000        -9999.0
# 2005-07-05 10:45:00    200507051030  200507051100 -0.240645                  2.0         2.387860    452.373 -0.040543                  2.0         -0.186496   12.37420  -0.090274                 1.0         1.163710     0.006672  108.8060  0.013876         -9999.0         -9999.0          -9999.0      -9999.0 -9999.00000 -9999.0000   -9999.0    -9999.000        -9999.0
# ...                             ...           ...       ...                  ...              ...        ...       ...                  ...               ...        ...        ...                 ...              ...          ...       ...       ...             ...             ...              ...          ...         ...        ...       ...          ...            ...
# 2022-12-31 22:45:00    202212312230  202212312300  1.202730                  0.0         0.069432    421.579  5.985080                  1.0          0.108045    8.64158 -25.894300                 0.0        -0.674189     0.131824   54.6935  0.660836         -9999.0         -9999.0          -9999.0          0.0    10.40080    62.5504   -9999.0      278.846            0.0
# 2022-12-31 23:15:00    202212312300  202212312330 -1.475100                  2.0         0.029368    422.114 -7.078160                  1.0         -0.071440    8.61249  11.805700                 2.0        -2.362870     0.178685   88.4788  0.535631         -9999.0         -9999.0          -9999.0          0.0     8.92672    68.8316   -9999.0      271.380            0.0
# 2022-12-31 23:45:00    202212312330  202301010000  4.104030                  0.0        -0.038807    421.408 -0.861379                  0.0          0.522764    8.82527 -52.880700                 0.0         0.081891     0.095143  108.9400  0.586568         -9999.0         -9999.0          -9999.0          0.0     8.97778    70.3356   -9999.0      277.935            0.0
# 2023-01-01 00:15:00    202301010000  202301010030  1.548310                  0.0         0.795844    436.395  0.861332                  1.0          1.341130    9.39573 -12.411200                 0.0        14.418000     0.096896   56.4159  0.987496         -9999.0         -9999.0          -9999.0      -9999.0 -9999.00000 -9999.0000   -9999.0    -9999.000        -9999.0
# 2023-01-01 00:45:00    202301010030  202301010100  4.004120                  1.0        -0.028557    435.857  5.642410                  1.0         -0.359339    9.24279 -34.806900                 1.0         0.274690     0.091799   59.9956  1.484260         -9999.0         -9999.0          -9999.0      -9999.0 -9999.00000 -9999.0000   -9999.0    -9999.000        -9999.0
#
# [306657 rows x 25 columns]

# %% [markdown]
# # Plot some key variables

# %%
fig = plt.figure(facecolor='white', figsize=(16, 9))
gs = gridspec.GridSpec(1, 3)  # rows, cols
ax_fc = fig.add_subplot(gs[0, 0])
ax_le = fig.add_subplot(gs[0, 1])
ax_ta = fig.add_subplot(gs[0, 2])
HeatmapDateTime(ax=ax_fc, series=data_fluxnet['FC_1_1_1'], vmin=-50, vmax=50).plot()
HeatmapDateTime(ax=ax_le, series=data_fluxnet['LE_1_1_1'], vmin=-100, vmax=1000).plot()
HeatmapDateTime(ax=ax_ta, series=data_fluxnet['TA_1_1_1'], vmin=-50, vmax=50).plot()
ax_fc.set_title("FC_1_1_1", color='black')
ax_le.set_title("LE_1_1_1", color='black')
ax_ta.set_title("TA_1_1_1", color='black')
ax_le.tick_params(left=True, right=False, top=False, bottom=True,
                     labelleft=False, labelright=False, labeltop=False, labelbottom=True)
ax_ta.tick_params(left=True, right=False, top=False, bottom=True,
                     labelleft=False, labelright=False, labeltop=False, labelbottom=True)

# %% [markdown]
# # Finish

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished {dt_string}")
# Out:
# Finished 2023-04-24 02:59:35
