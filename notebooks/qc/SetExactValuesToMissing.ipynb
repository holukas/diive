# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:32px; display:block;'>
# <b>
#     Set exact values to missing¶
# </b>
# </span>

# %% [markdown]
# ---
# **Notebook version**: `1` (6 Jun 2025)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %% [markdown]
# # **Description**

# %% [markdown]
# - In a pandas Series, set records matching *values* to missing values

# %% [markdown]
# </br>

# %% [markdown]
# # **Imports**

# %%
import importlib.metadata
import warnings
from datetime import datetime

import numpy as np
import pandas as pd

from diive.pkgs.corrections.setto_missing import set_exact_values_to_missing

warnings.filterwarnings('ignore')
version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
# Out:
# diive version: v0.87.0

# %% [markdown]
# </br>

# %% [markdown]
# # **Docstring**

# %%
help(set_exact_values_to_missing)
# Out:
# Help on function set_exact_values_to_missing in module diive.pkgs.corrections.setto_missing:
#
# set_exact_values_to_missing(series: pandas.core.series.Series, values: list, showplot: bool = False) -> pandas.core.series.Series
#     Set records matching *values* to missing values.
#
#     Args:
#         series: Data for variable that is corrected
#         values: List of floats that will be set to missing values
#         showplot: Show plot
#
#     Returns:
#         Corrected series

# %% [markdown]
# </br>

# %% [markdown]
# # **Create example data**
# - Create 1000 records of random numbers in 10min time resolution as `replicate`
# - Then add a constant offset of `4.2` to data and store as `measurement`

# %%
series = [1, 2, 0, 4, 5, 6, 7, 0, 9, 10]
series = pd.Series(series)
series.name = "testdata"
corrected_series = set_exact_values_to_missing(series=series, values=[0, 1, 10], showplot=True)
print(corrected_series)
# Out:
# [set_exact_values_to_missing]  running set_exact_values_to_missing ...
# Correction: set exact values to missing
#     Variable: input_data
#     Number of records set to missing: 4
#     Locations of records set to missing: [0, 2, 7, 9]
# 0    NaN
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    6.0
# 6    7.0
# 7    NaN
# 8    9.0
# 9    NaN
# Name: testdata, dtype: float64

# %% [markdown]
# </br>

# %% [markdown]
# # End of notebook

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished {dt_string}")
# Out:
# Finished 2025-06-06 11:55:13
